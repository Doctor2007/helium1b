# %% [markdown]
# # Data Exploration for Waste Management in Ghana
#
# This notebook is dedicated to exploratory data analysis (EDA) of waste management data in Ghana. The aim is to gain initial insights into the data, identify patterns, and prepare for further analysis.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set visualisation style
sns.set(style='whitegrid')

# %%
# Load the data
trade_data = pd.read_csv('data/raw/micro_data_trade_2022.csv')

# Display the first few rows of the waste data
trade_data.head()
# Out:
#    Year    Month Tradeflow Partner_Country  HS2  \
# 0  2022  January    Export         Algeria   18
# 1  2022  January    Export         Algeria   18
# 2  2022  January    Export         Algeria   18
# 3  2022  January    Export         Algeria   18
# 4  2022  January    Export          Angola   84
#
#                                      Description_HS2   HS4  \
# 0                       Cocoa and cocoa preparations  1803
# 1                       Cocoa and cocoa preparations  1804
# 2                       Cocoa and cocoa preparations  1805
# 3                       Cocoa and cocoa preparations  1805
# 4  Nuclear reactors, boiliers, mchy & mech applia...  8425
#
#                                      Description_HS4        HS10  \
# 0               Cocoa paste, whether or not defatted  1803100000
# 1                          Cocoa butter, fat and oil  1804001000
# 2  Cocoa powder, not containing added sugar or ot...  1805001000
# ...

# %% [markdown]
# ## Initial Findings
#
# 1. The distribution of waste types indicates the most prevalent types of waste in Ghana.
# 2. The correlation matrix provides insights into relationships between different trade variables.
#
# Further analysis will be conducted to explore these findings in detail.
